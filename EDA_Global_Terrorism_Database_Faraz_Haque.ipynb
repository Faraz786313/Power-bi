# %% [markdown]
# <a href="https://colab.research.google.com/github/Faraz786313/Power-bi/blob/main/EDA_Global_Terrorism_Database_Faraz_Haque.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA Global Terrorism Database
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Faraz Haque

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Project aims to analyse the Global terrorism Database (GTD) and gain valueble insights on the matter. As we all are aware that terrorism has been a complex are emminat matter in the current times. To tackle this issue we will use GTD provided by Study of Terrorism and Response to Terrorism (START) with over 180000 terrorist attacks recoreded to gain insights on motive, geographical locations,means etc.
#
# 1.    Methodology :
#
#
# *   **Data Cleaning:**
#
# Handle missing values, remove duplicates, and ensure data consistency using pandas and Numpy libraries
# Address any anomalies or inconsistencies in the dataset.
# *   **Exploratory Data Analysis (EDA):**
#
# Use Seaborn and Matplotlib for data visualizations.
# Explore trends, patterns, and distributions related to terrorist attacks.
# Investigate factors such as attack frequency, geographical hotspots, attack types, and Frequent organizations,etc.

# %% [markdown]
# # **GitHub Link -**
# https://github.com/Faraz786313

# %% [markdown]
# # **GDT dataseeet google drive link -**
# https://colab.research.google.com/drive/1oCjwXsMDUG0Mn5-wLfQ8i6u7mZzPTEFu?usp=sharing

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This analysis Aims to find deeper insights on the data provided by START and answer key questions.
#
#
#  **Insights and Interpretations:**
#
# ***Analyze the data to gain valuable insights:***
#
#
#
# *   Which regions or countries experience the highest number of attacks?
# *   What are the common tactics used by terrorist groups?
#
#
# *   How does the nature of the target impact attack outcomes?
#
# *   Explore correlations between variables.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Mount the drive to access csv file from google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load the Database with latin-1 as its encoding
database = "/content/drive/MyDrive/Colab Notebooks/Global Terrorism Data.csv"
df = pd.read_csv(database, encoding = "latin-1")
# Out:
# <ipython-input-4-a5cfdc383612>:3: DtypeWarning: Columns (5,7,32,34,62,63,64,77,80,91,93,95,97,115,116,122) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(database, encoding = "latin-1")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    index       eventid  year  Month  Day approxdate  extended resolution  \
# 0      0  197000000001  1970      7    2        NaN         0        NaN
# 1      1  197000000002  1970      0    0        NaN         0        NaN
# 2      2  197001000001  1970      1    0        NaN         0        NaN
# 3      3  197001000002  1970      1    0        NaN         0        NaN
# 4      4  197001000003  1970      1    0        NaN         0        NaN
#
#    country             Country  region                       Region    state  \
# 0       58  Dominican Republic       2  Central America & Caribbean      NaN
# 1      130              Mexico       1                North America  Federal
# 2      160         Philippines       5               Southeast Asia   Tarlac
# 3       78              Greece       8               Western Europe   Attica
# 4      101               Japan       4                    East Asia  Fukouka
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Total Number of rows:",df.shape[0])

print("Total Number of columns:",df.shape[1])
# Out:
# Total Number of rows: 181691
# Total Number of columns: 137

# %% [markdown]
# We have approximatly 180K incident reports of terrorism in this particular dataset

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 137 entries, index to Casulaties
# dtypes: float64(53), int64(26), object(58)
# memory usage: 189.9+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
obj = df.isnull().sum()
print(obj.to_string())
# Out:
# index                      0
# eventid                    0
# year                       0
# Month                      0
# Day                        0
# approxdate            172452
# extended                   0
# resolution            179471
# country                    0
# Country                    0
# region                     0
# Region                     0
# state                    421
# city                     435
# latitude                4556
# longitude               4557
# specificity                6
# vicinity                   0
# location              126196
# Summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           152680
# alternative_txt       152680
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# AttackType                 0
# attacktype2           175377
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(15, 11))

# Define a custom colormap with more vibrant colors
cmap = sns.color_palette("viridis", as_cmap=True)

# Create a heatmap with custom colormap and gridlines
sns.heatmap(df.isnull().corr(), vmin=-1, vmax=1, annot=True, cmap=cmap,
            linewidths=0.5, linecolor='black', cbar_kws={'shrink': .75, 'orientation': 'horizontal'})

# Set the labels and title with customized fonts and sizes
plt.xlabel("Columns", fontsize=14, fontweight='bold')
plt.ylabel("Columns", fontsize=14, fontweight='bold')
plt.title("Correlation of Missing Values", fontsize=18, fontweight='bold')

# Show the heatmap
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# # Insights on Dataset so far!
#
# *   This dataset consists of Terrorist attacks over years and months listing no. of causalties, people injured , organisation involved, regions and methods used. This gives us an opptuninty to perform comprensive analysis and gain valuable insights.
# *   The dataset consists of 181691 rows and 135 columns.
#
#
# *   The datatypes in the dataset set mostly comprises of INT64,Float64 and Object.
#
# *   While the dataset does not have duplicated values and the data types for each atrribute are correct, the dataset does have numerous missing values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns.tolist()
# Out:
# ['index',
#  'eventid',
#  'year',
#  'Month',
#  'Day',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'Country',
#  'region',
#  'Region',
#  'state',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'Summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'AttackType',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'Target_type',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'Target',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'Group',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
# Dataset Describe
df.describe()
# Out:
#                index       eventid           year          Month  \
# count  181691.000000  1.816910e+05  181691.000000  181691.000000
# mean    90845.000000  2.002705e+11    2002.638997       6.467277
# std     52449.818217  1.325957e+09      13.259430       3.388303
# min         0.000000  1.970000e+11    1970.000000       0.000000
# 25%     45422.500000  1.991021e+11    1991.000000       4.000000
# 50%     90845.000000  2.009022e+11    2009.000000       6.000000
# 75%    136267.500000  2.014081e+11    2014.000000       9.000000
# max    181690.000000  2.017123e+11    2017.000000      12.000000
#
#                  Day       extended        country         region  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       15.505644       0.045346     131.968501       7.160938
# std         8.814045       0.208063     112.414535       2.933408
# min         0.000000       0.000000       4.000000       1.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# # Description of the Variable which would be usefull during our analysis.
# **Event ID (eventid):** A unique identifier for each terrorist event.
#
# **Year (iyear):** The year in which the event occurred.
#
# **Month (imonth):** The month of the event.
#
# **Day (iday):** The day of the event.
#
# **Extended (extended):** Indicates whether the duration of the event extended beyond **24** hours.
#
# **Country (country):** Numeric code representing the country where the event took place.
#
# **Country Name (country_txt):** The name of the country.
#
# **Region (region):** Numeric code representing the region (e.g., Middle East & North Africa, South Asia).
#
# **Region Name (region_txt):** The name of the region.
#
# **Location (location):** Specific location of the event (e.g., city, province).
#
# **Summary (summary):** A brief description of the event.
#
# **Attack Type (attacktype1):** Numeric code representing the type of attack (e.g., bombing, assassination).
#
# **Attack Type Name (attacktype1_txt):** The name of the attack type.
#
# **Target Type (targtype1):** Numeric code representing the target type (e.g., civilians, government).
#
# **Target Type Name (targtype1_txt):** The name of the target type.
# Perpetrator Group (gname): The name of the terrorist group responsible for the attack.
#
# **Number of Perpetrators (nperps):** The count of perpetrators involved.
#
# **Number of Perpetrators Captured (nperpcap):** The count of captured perpetrators.
#
# **Number of Victims Killed (nkill):** The number of people killed in the attack.
#
# **Number of Victims Wounded (nwound):** The number of people wounded in the attack.
#
# **Property Damage (property):** Indicates whether property was damaged.
#
# **Hostage Situation (ishostkid):** Indicates whether hostages were taken.
#
# **Number of Fatalities (nkill):** Total fatalities in the incident.
#
# **Number of Injured (nwound):** Total people injured in the incident.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# renaming columns to make it easier for analysis
df.rename(columns={'iyear':'year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type'},inplace=True)

# %%
# filling missing values in wounded and no. of killed columns and having data type as int to make analysis accurate.
df['Wounded'] = df['Wounded'].fillna(0).astype(int)
df["killed"] = df["killed"].fillna(0).astype(int)
# creating a column casualties to better understand the damage casued
df["Casulaties"] = df['Wounded'] + df["killed"]

# %%
#checking if fields required for analysis have missing values changes made
print("Country",df['Country'].isnull().sum())
print("Region",df['Region'].isnull().sum())
print("Attack_type", df['AttackType'].isnull().sum())
print("Killed",df['killed'].isnull().sum())
print("wounded", df['Wounded'].isnull().sum())
print("Group",df['Group'].isnull().sum())
print("hostages", df["ishostkid"].isnull().sum())
print("property",df["property"].isnull().sum())
# Out:
# Country 0
# Region 0
# Attack_type 0
# Killed 0
# wounded 0
# Group 0
# hostages 178
# property 0

# %% [markdown]
# Hostages values are ignored as the value 0 represents no hostages taken which is being count as missing values by the isnull() method

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Wounded and Killed had NAN values which were replaced by 0 as the fields are not numeric nature.Futhermore the names of the fields were changed making it easier to understand and use

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 attacks over the years
# create a plot set figure size count by number of attacks over the years and display the plot
# count plot will be used as we need to see number of attacks over the years
plt.figure(figsize=(13,6))
sns.countplot(x= "year", data= df)
#axis rotated for readability
plt.xticks(rotation = 45)
plt.title("Terrorist Attacks over the years")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### *A count Plot was used as we needed to find the number of terrorist attacks over the course of time(years)*

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### *It can be seen from the chart above there has been a spike in number of terrorist attacks from 2012-2017 with 2014 being the highest siting at 16903 attacks in that year alone.*

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 Attacks over the year by region by creating cross table with regionwise attacks over the years
cross_tab_reg = pd.crosstab(df["year"], df["Region"])
cross_tab_reg = cross_tab_reg[cross_tab_reg.sum().sort_values(ascending =False).index]
# Define colorblind-friendly colors
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
cross_tab_reg.plot(kind = "line",figsize = (13,6), color=colors)
plt.title("Number of attacks over the years by region")
plt.ylabel("Number of attacks")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###*Line charts allow us to observe trends and patterns over time.By connecting data points with lines, we can easily identify increases, decreases, or fluctuations in the number of attacks for each region.Each region’s line can be visually compared to others on the same chart.We can pinpoint specific years with high or low attack rates.*

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###**General Increase:** Overall, there is a general increase in the number of attacks across all regions over time.
#
# ###**Sharp Rise in Middle East & North Africa and South Asia:** Since around 2000, the Middle East & North Africa and South Asia regions have seen a significant surge in attacks.
#
# ###**Western Europe Decline:** Western Europe had a peak in attacks around the mid-1980s but has since experienced a substantial decline.
#
# ### **Central America & Caribbean:** This region had a high number of attacks during the 1980s but decreased afterward.
#
# ### **Other Regions:** Sub-Saharan Africa and Southeast Asia show an increase, but not as pronounced as in the Middle East & North Africa or South Asia.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 Most common Attack type
plt.figure(figsize=(13,6))
sns.countplot(x= "AttackType", data= df, hue ="year")
#axis rotated for readability
plt.xticks(rotation = 45)
plt.title("Weapons used in Terrorist Attacks over years ")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### **count plot provides us with a overview data with respect to category and valuecounts giving us an  accurate representation of attack Types over the years**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Although various kinds of attacks are still prevelant in the past and recent times, armed assault and bombing take the lead in present,especially from the year 2008-2016**

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 Terrorist incidents by city

from wordcloud import WordCloud
# Filter and get a Series of non-null state values from the DataFrame
cities = df["state"].dropna()
plt.figure(figsize=(10,10))
# Create a word cloud figure
cities_chart = WordCloud(background_color='white', width=512, height=384).generate(' '.join(cities))
plt.title("Terrorist attacks by cities")
plt.axis("off")
plt.imshow(cities_chart)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Word clouds provide a concise and visual summary of text data.
# They highlight the most frequent or important terms, making it easy to grasp key themes at a glance.
# The size of each word corresponds to its frequency.
# We can quickly identify which terms occur frequently (larger font) and which are less common (smaller font)
# Word clouds are visually appealing and engage users.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### *The word cloud suggests that certain cities are strongly associated with terrorist attacks.Regions like the Middle East (e.g., Baghdad, Anbar, Saladin), South Asia (e.g., Kashmir, Jammu), and other conflict-prone areas appear prominently.The presence of “Unknown” indicates that some attacks may not be specifically attributed to a city or region.*
#
#  **However, its essential to recognize that word clouds have limitations:
# They lack context and do not provide detailed information.**

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 which countries are most afffected by these terror attacks
# filtering top 25 countires
attack_countries = df['Country'].value_counts()[:25]
plt.figure(figsize=(10,5))
sns.barplot(x=attack_countries.index, y=attack_countries.values)
# using ticks for better label visibilty
plt.xticks(rotation= 90)
plt.title('Top 25 Countries Affected by Terrorist Attacks')
plt.xlabel('Countries')
plt.ylabel('Count of Attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We create a dataframe with the count of countries appearing in the dataset showcasing the frequency at which these countries have been attacked. We use a bar plot as we want to show a distribution of data points and perform a comparison of metric values across different subgroups of our data with the countries along with there frequency of attacks giving us a better insight on the affected countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above list, plots the top 25 countries affected by terror attacks and we can have the following deduction from the above countplot:
#
#
# *   Iraq is placed first and is most affected by acts of terrorism placing it at immediate urgency to re-evaluate its security measures.
# *   Pakistan is ranked second in terrorist-led activities mainly becasue due to its geopolitical context.
#
#
# *   Followed by Afganisthan and India which also have had considerably large number of attacks and the need to emphasize on security concerns is of utmost importance.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 Which terrorist organistation is the most prevalant among all.
# filtering top 10 terrorist groups
Organizations = df['Group'].value_counts()[1:11]
plt.figure(figsize=(10,5))
sns.barplot(x=Organizations.values, y=Organizations.index)
# using ticks for better label visibilty
plt.xticks(rotation= 90)
plt.title('Top 10 Terrorist Organizations')
plt.xlabel('Count')
plt.ylabel('Groups')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We create a dataframe with the count of terror Group appearing in the dataset showcasing prevelance of each group throughout the dataset. We use a bar plot as we want to  perform a comparison of metric values across different subgroups of our data with different groups along with there frequency of attacks giving us a better insight on the prevelance of these groups.

# %%
print("Top 10 Terrorist Organization")
print(Organizations)
# Out:
# Top 10 Terrorist Organization
# Group
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Name: count, dtype: int64

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From what we can see **Taliban** is the leading and the most promient terrorist organisation in the world playing a major role in global terrorism.
#
# **Islamic State of Iraq and the Levant (ISIL)** is placed second falling just a little short of tabliban but it's impact still cannot be undermined.
# Although **Shining Path (SL) and Farabundo Marti National Liberation Front (FMLN)** are trailing right behind ISIL their presence is still very prominent and has had major impact negativly on global terrorism.
#
#
# **Analysis and visulisation done up until now have shed light on the major organisations and their impact on regions and countries  revaling important infromation better equipping us to prepare against attacks and strategise our safety.**

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 Number of people killed by each terror group

people_killed = df[["Group","killed"]].groupby(["Group"]).sum().sort_values("killed",ascending = False).head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=people_killed.killed.values, y=people_killed.index)
# using ticks for better label visibilty
plt.xticks(rotation= 90)
plt.title(' Number of people killed by each Terrorist Organizations')
plt.xlabel('Casualties')
plt.ylabel('Groups involved')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### *The filtered dataset is grouped by on basis of groups and killed thus using a bar plot to visulaise the data makes it easier to compare which terrorist organisation has killed most number of people.*

# %%
print("Number of People Killed by Each Terrorist Group:")
print(people_killed)
# Out:
# Number of People Killed by Each Terrorist Group:
#                                                   killed
# Group
# Unknown                                           112367
# Islamic State of Iraq and the Levant (ISIL)        38923
# Taliban                                            29410
# Boko Haram                                         20328
# Shining Path (SL)                                  11601
# Liberation Tigers of Tamil Eelam (LTTE)            10989
# Al-Shabaab                                          9330
# Farabundo Marti National Liberation Front (FMLN)    8065
# Nicaraguan Democratic Force (FDN)                   6662
# Tehrik-i-Taliban Pakistan (TTP)                     6042

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  **Unknown Group**
#
#
# *   The “Unknown” group has caused the highest number of casualties, with 112,367 people killed.
# *   The term “Unknown” refers to incidents where the responsible group or organization is unidentified or not specified.
#
# **Other Notable Groups**
#
#
# *   ISIL (Islamic State of Iraq and the Levant): ISIL is the second-highest contributor to casualties, with 38,923 people killed.
# Taliban: The Taliban ranks third, causing 29,410 casualties.
# *   Boko Haram: Boko Haram is responsible for 20,328 deaths
#
# *   Shining Path (SL): This group has caused 11,601 casualties
# *   Liberation Tigers of Tamil Eelam (LTTE): LTTE has caused 10,989 deaths.
#
# **Other Listed Groups**
# *   Al-Shabaab, Farabundo Marti National Liberation Front (FMLN), Nicaraguan Democratic Force (FDN), and Tehrik-i-Taliban Pakistan (TTP) have also contributed to casualties.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 people killed over the years
people_killed = df[["year","killed"]].groupby(["year"]).sum().sort_values("killed",ascending = False)

plt.figure(figsize=(10,5))
sns.barplot(x=people_killed.index, y=people_killed.killed.values)
# using ticks for better label visibilty
plt.xticks(rotation= 90)
plt.title(' Number of people killed each year')
plt.xlabel('year')
plt.ylabel('Casualties')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason remains the same to use bar plot. As mentioned before as we need to compare values of number of killed vs years we use bar plot

# %%
print("Top 10 Years with the Highest Number of People Died:")
print(people_killed.nlargest(10, 'killed'))
# Out:
# Top 10 Years with the Highest Number of People Died:
#       killed
# year
# 2014   44490
# 2015   38853
# 2016   34871
# 2017   26445
# 2013   22273
# 2012   15497
# 2007   12824
# 1997   10924
# 1984   10450
# 1992    9742

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The years 2014, 2015, and 2016 had relatively high numbers of casualties (44,490, 38,853, and 34,871, respectively).
# These years likely correspond to significant conflict or terrorist activities.
# The number of casualties decreased in 2017 (26,445).
# This decline may indicate improved security measures, peace efforts, or changes in conflict dynamics although it cannot be ignored that the number casualties is still large although it may be less compared to casualties in 2014.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9  Number of People killed due to each Attack type

# filtering data and sorting it according number of killed while we have grouped the data by attack type
peoplekilled_attacktype = df[["killed","AttackType"]].groupby(["AttackType"]).sum().sort_values("killed",ascending = False)
plt.figure(figsize=(10,5))
sns.barplot(x=peoplekilled_attacktype.killed.values, y=peoplekilled_attacktype.index, palette="cubehelix")
# using ticks for better label visibilty
plt.xticks(rotation= 90)
plt.title(' Number of people killed by each Attack Type')
plt.xlabel('Number of Casualties')
plt.ylabel('AttackType')
plt.show()
# Out:
# <ipython-input-27-ee504b026cee>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=peoplekilled_attacktype.killed.values, y=peoplekilled_attacktype.index, palette="cubehelix")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason remains the same to use bar plot. As mentioned before as we need to compare values of number of killed with respect to attack type thus using a bar plot is the most apporitate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %%
print('Number of people killed by each Attack Type')

print(peoplekilled_attacktype)
# Out:
# Number of people killed by each Attack Type
#                                      killed
# AttackType
# Armed Assault                        160297
# Bombing/Explosion                    157321
# Unknown                               32381
# Assassination                         24920
# Hostage Taking (Kidnapping)           24231
# Hostage Taking (Barricade Incident)    4478
# Hijacking                              3718
# Facility/Infrastructure Attack         3642
# Unarmed Assault                         880

# %% [markdown]
# As we can see from the dataFrame and the bar plot above the most number of people killed are by **Armed Assault** standing at a shocking 160k people killed.
#
# **Bombing and explosion** is next on the list for most people killed standing at 157k people killed.
#
# **Unknown** category suggests the nature of attack is not clear suggesting difficulty finding the nature of attack by governments and other anti-terrorist organisation.
#
# **Assassination** is another notable category, given its nature of attack, people killed under this category is still substantial.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 number of people wounded by each attackType

# filtering data and sorting it according number of wounded while we have grouped the data by attack type
Wounded_by_attacktype = df[["Wounded","AttackType"]].groupby(["AttackType"]).sum().sort_values("Wounded",ascending = False)
plt.figure(figsize=(10,5))
sns.barplot(x=Wounded_by_attacktype.Wounded.values, y=Wounded_by_attacktype.index, palette="cubehelix")
# using ticks for better label visibilty
plt.xticks(rotation= 90)
plt.title(' Number of people wounded by each Attack Type')
plt.xlabel('Number of wounded')
plt.ylabel('AttackType')
plt.show()
# Out:
# <ipython-input-29-e4a143ff352d>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Wounded_by_attacktype.Wounded.values, y=Wounded_by_attacktype.index, palette="cubehelix")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason remains the same to use bar plot. As mentioned before as we need to compare values of number of wounded with respect to attack type thus using a bar plot is the most apporitate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %%
print("Number of people wounded by each attackType")
print(Wounded_by_attacktype)
# Out:
# Number of people wounded by each attackType
#                                      Wounded
# AttackType
# Bombing/Explosion                     372686
# Armed Assault                          77365
# Hijacking                              17001
# Unknown                                14725
# Unarmed Assault                        14027
# Assassination                          13887
# Hostage Taking (Kidnapping)             6446
# Hostage Taking (Barricade Incident)     3966
# Facility/Infrastructure Attack          3765

# %% [markdown]
# **Bombing/Explosion:** A staggering 372,686 people were wounded in incidents involving bombings or explosions.
#
# **Armed Assault:** Approximately 77,365 individuals were wounded in armed assault situations.
#
# **Hijacking:** Hijacking events resulted in 17,001 people being wounded.
#
# **Unknown:** The category labeled “Unknown” saw 14,725 people wounded, although the specific circumstances remain unclear.
#
# **Unarmed Assault:** Surprisingly, even in unarmed assault scenarios, 14,027 people sustained injuries.
#
# **Assassination:** Assassination attempts led to 13,887 people being wounded.
#
# **Hostage Taking (Kidnapping):** Incidents involving hostage-taking or kidnapping caused injuries to 6,446 individuals.
#
# **Hostage Taking (Barricade Incident):** In barricade incidents with hostages, 3,966 people were wounded.
#
# **Facility/Infrastructure Attack:** Attacks on facilities or infrastructure resulted in 3,765 people being wounded.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11  number of people taken hostages by each Terrorist group

# filtering data and sorting it according number of hostage taken while we have grouped the data by Terrorist Groups
hostage_by_group = df[["Group", "ishostkid"]].groupby(["Group"]).sum().sort_values("ishostkid",ascending = False).head(15)
plt.figure(figsize=(10,5))
sns.barplot(x=hostage_by_group.ishostkid.values, y=hostage_by_group.index,  palette="cubehelix")
# using ticks for better label visibilty
plt.xticks(rotation= 90)
plt.title(' Number of people taken hostage by each Terrorist organisation')
plt.xlabel('Number of Hostages')
plt.ylabel('Group')
plt.show()
# Out:
# <ipython-input-31-ab670c1523d9>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=hostage_by_group.ishostkid.values, y=hostage_by_group.index,  palette="cubehelix")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason remains the same to use bar plot. As mentioned before as we need to compare values of number of hostage taken with respect to Group thus using a bar plot is the most apporitate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The plot  shows the number of people taken hostage by each terrorist organization. Here are some insights:
#
# 1. The group with the **highest number of hostages** is the **Unknown** group with **3332** hostages. This could be due to the fact that many incidents of terrorism are not claimed by any group, or the perpetrators remain unidentified.
#
# 2. The **Islamic State of Iraq and the Levant (ISIL)** is the known group with the second highest number of hostages, totalling **587**.
#
# 3. The **Communist Party of India - Maoist (CPI-Maoist)** and the **National Liberation Army of Colombia (ELN)** have similar numbers of hostages, with **373** and **369** respectively.
#
# 4. The **Revolutionary Armed Forces of Colombia (FARC)** has taken **348** hostages, which is slightly less than the CPI-Maoist and ELN.
#
# 5. The **Maoists**, **New People's Army (NPA)**, and **Al-Shabaab** have also taken a significant number of hostages, with numbers ranging from **282** to **293**.
#
# 6. The **Abu Sayyaf Group (ASG)**, **Taliban**, **Farabundo Marti National Liberation Front (FMLN)**, **Shining Path (SL)**, **Kurdistan Workers' Party (PKK)**, **Houthi extremists (Ansar Allah)**, and **Tehrik-i-Taliban Pakistan (TTP)** have taken fewer hostages, with numbers ranging from **152** to **189**.
#
# This data provides a snapshot of the hostage-taking activities of various terrorist organizations. However, it's important to note that the number of hostages taken does not necessarily correlate with the overall threat level or capacity of a terrorist organization. Other factors such as the people wounded, killed, AttackType and resources, and geographical reach also play a crucial role.

# %% [markdown]
# # **Conclusion**

# %%
df.head()
# Out:
#    index       eventid  year  Month  Day approxdate  extended resolution  \
# 0      0  197000000001  1970      7    2        NaN         0        NaN
# 1      1  197000000002  1970      0    0        NaN         0        NaN
# 2      2  197001000001  1970      1    0        NaN         0        NaN
# 3      3  197001000002  1970      1    0        NaN         0        NaN
# 4      4  197001000003  1970      1    0        NaN         0        NaN
#
#    country             Country  region                       Region    state  \
# 0       58  Dominican Republic       2  Central America & Caribbean      NaN
# 1      130              Mexico       1                North America  Federal
# 2      160         Philippines       5               Southeast Asia   Tarlac
# 3       78              Greece       8               Western Europe   Attica
# 4      101               Japan       4                    East Asia  Fukouka
#
# ...

# %%
from google.colab import files
df.to_csv(database, index=False)
files.download(database)

# %% [markdown]
# **Summary**
#
# 1. There was a spike in terrorist attacks from 2012-2017, with the highest number of attacks (16,903) occurring in 2014.
# 2. There has been a general increase in attacks across all regions over time, with a sharp rise in the Middle East & North Africa and South Asia since 2000. Western Europe has seen a decline since the mid-1980s, while Central America & Caribbean saw a decrease after the 1980s.
# 3. Armed assault and bombing have become the most prevalent types of attacks, especially from 2008-2016.
# 4. Certain cities in the Middle East and South Asia are strongly associated with terrorist attacks. However, word clouds lack context and do not provide detailed information.
# 5. Iraq, Pakistan, Afghanistan, and India are among the top countries affected by terror attacks.
# 6. The Taliban is the leading terrorist organization globally, followed by the Islamic State of Iraq and the Levant (ISIL).
# 7. The "Unknown" group has caused the highest number of casualties (112,367), followed by ISIL (38,923) and the Taliban (29,410).
# 8. The years 2014-2016 had high numbers of casualties, with a decrease in 2017, possibly due to improved security measures or changes in conflict dynamics.
# 9. The most number of people were killed by armed assault (160k) and bombing/explosion (157k).
# 10. Bombing/explosion resulted in the most injuries (372,686), followed by armed assault (77,365) and hijacking (17,001).
# 11. The "Unknown" group has taken the most hostages (3332), followed by ISIL (587) and the Communist Party of India - Maoist (CPI-Maoist) and the National Liberation Army of Colombia (ELN) with similar numbers.
#
# **Conclusion**
#
# The data provides a comprehensive overview of global terrorism trends, highlighting the regions and countries most affected, the types of attacks prevalent, and the terrorist organizations involved. This information is crucial for strategizing safety measures and preparing against attacks. However, it's important to note that the number of hostages taken does not necessarily correlate with the overall threat level or capacity of a terrorist organization. Other factors such as the number of people wounded, killed, and the type of attack also play a crucial role. The presence of "Unknown" in many categories indicates the challenges in attributing attacks to specific groups or regions.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
